# %% [markdown]
# ### CryoParticleSegment

# %%
# %pip install torchinfo -qq
# %pip install -U git+https://github.com/qubvel/segmentation_models.pytorch -qq
# %pip install https://github.com/soft-matter/trackpy/archive/master.zip -qq
# %pip install pycuda -qq
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 61.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 33.1 MB/s eta 0:00:00
#   Building wheel for segmentation_models_pytorch (pyproject.toml) ... done
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done
#      \ 10.7 MB 9.1 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
#   Building wheel for trackpy (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.8 MB/s eta 0:00:00
#   Building wheel for pycuda (pyproject.toml) ... done

# %% [markdown]
# ## ⭐ Setup
# You must run all codes under this category.

# %% [markdown]
# ### ✅ Directory Settings

# %%
# @title  { display-mode: "form" }

IMAGE_DIR = "/content/drive/MyDrive/research_xs/dataset/10081/processed_micrographs_np_split" # @param {type:"string"}
LABEL_DIR = "/content/drive/MyDrive/research_xs/dataset/10081/micrographs_ground_np" # @param {type:"string"}
RESULT_DIR = "/content/drive/MyDrive/research_xs/results/10081_test/unet_eb5_dice_postcrf/" # @param {type:"string"}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title  { display-mode: "form" }
# @markdown Detect whether using folder in Google Drive as **`RESULT DIR`**📁.

if "content" in IMAGE_DIR.split("/")[:3] or "content" in LABEL_DIR.split("/")[:3]:
  try:
    from google.colab import drive
    drive.mount('/content/drive')
    # !rm -r /content/sample_data
    if "content" in IMAGE_DIR.split("/")[:3]:
      # !cp -r {IMAGE_DIR} /content/image_dir
      IMAGE_DIR = "/content/image_dir"
    if "content" in LABEL_DIR.split("/")[:3]:
      # !cp -r {LABEL_DIR} /content/label_dir
      LABEL_DIR = "/content/label_dir"
  except:
    pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMAGE_DIR = "/content/image_dir"

# %%
# @title  { display-mode: "form" }
# @markdown Source code directory.
SRC_DIR = "/content/drive/MyDrive/00_Image\ meeting/Researches/01_Scratchpad/seg_src/CryoParticleSegment-main/Modeling" # @param {type:"string"}

if True:
  # !cp -rf {SRC_DIR}/* /content/
else:
  # !cp {SRC_DIR}/convcrf.py /content/convcrf.py
  # !cp {SRC_DIR}/dataset.py /content/dataset.py
  # !cp {SRC_DIR}/lr_scheduler.py /content/lr_scheduler.py
  # !cp {SRC_DIR}/metrics.py /content/metrics.py
  # !cp {SRC_DIR}/model.py /content/model.py
  # !cp {SRC_DIR}/trainer.py /content/trainer.py
  # !cp {SRC_DIR}/utils.py /content/utils.py

# %%
# %git clone https://github.com/netw0rkf10w/CRF.git
# %cd CRF
# !python setup.py install
# Out:
# /content/CRF_main
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating src/CRF.egg-info
# writing src/CRF.egg-info/PKG-INFO
# writing dependency_links to src/CRF.egg-info/dependency_links.txt
# writing top-level names to src/CRF.egg-info/top_level.txt
# writing manifest file 'src/CRF.egg-info/SOURCES.txt'
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:495: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'src/CRF.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/CRF.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/PermutohedralFiltering
# copying src/PermutohedralFiltering/PermutohedralFiltering.py -> build/lib.linux-x86_64-cpython-310/PermutohedralFiltering
# copying src/PermutohedralFiltering/setup.py -> build/lib.linux-x86_64-cpython-310/PermutohedralFiltering
# copying src/PermutohedralFiltering/__init__.py -> build/lib.linux-x86_64-cpython-310/PermutohedralFiltering
# creating build/lib.linux-x86_64-cpython-310/CRF
# copying src/CRF/__init__.py -> build/lib.linux-x86_64-cpython-310/CRF
# copying src/CRF/CRF.py -> build/lib.linux-x86_64-cpython-310/CRF
# copying src/CRF/sparsemax.py -> build/lib.linux-x86_64-cpython-310/CRF
# copying src/CRF/crfs_cpu.py -> build/lib.linux-x86_64-cpython-310/CRF
# copying src/CRF/convcrf.py -> build/lib.linux-x86_64-cpython-310/CRF
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'Permutohedral' extension
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/src
# creating build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering
# creating build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source
# creating build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/cpu
# x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/include/python3.10 -c src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp -o build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=Permutohedral -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp: In function ‘at::Tensor LatticeFilter_calculate(const at::Tensor&, const at::Tensor&, bool, float, float, float, bool)’:
# src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp:77:97: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    77 | ::Tensor positions = at::zeros({batch_size * num_super_pixels * pd}, input_tensor.type() );
#       |                                                                      ~~~~~~~~~~~~~~~~~^~
#
# In file included from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Tensor.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/function_hook.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/cpp_hook.h:2,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/variable.h:6,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/autograd/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/autograd.h:3,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include/torch/all.h:7,
#                  from /usr/local/lib/python3.10/dist-packages/torch/include/torch/extension.h:5,
#                  from src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.cpp:25:
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:30: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/cpu/LatticeFilterKernel.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-cpython-310/Permutohedral.cpython-310-x86_64-linux-gnu.so
# building 'Permutohedral_gpu' extension
# creating build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/gpu
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c src/PermutohedralFiltering/source/gpu/LatticeFilter.cu -o build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/gpu/LatticeFilter.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -arch=sm_70 -gencode=arch=compute_70,code=\"sm_70\" -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=Permutohedral_gpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu: In function ‘at::Tensor LatticeFilter_calculate_gpu(const at::Tensor&, const at::Tensor&, bool, float, float, float, bool, bool)’:
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:202:91: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   202 |     at::Tensor positions = at::zeros(
#       |                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:208:67: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   208 |     CHECK_INPUT(image_tensor);
#       |                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:209:64: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   209 |     CHECK_INPUT(positions);
#       |                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:225:1: note: declared here
#   225 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:213:44: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   213 |         auto ref_ptr = &(image_tensor.data<float>()[b * num_super_pixels * n_reference_channels]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:214:41: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |         auto pos_ptr = &(positions.data<float>()[b * num_super_pixels * pd]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:215:43: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   215 |         auto in_ptr = &(input_tensor.data<float>()[b * num_super_pixels * n_input_channels]);
#       |                 ~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# src/PermutohedralFiltering/source/gpu/LatticeFilter.cu:216:45: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   216 |         auto out_ptr = &(output_tensor.data<float>()[b * num_super_pixels * n_input_channels]);
#       |                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/src/PermutohedralFiltering/source/gpu/LatticeFilter.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/Permutohedral_gpu.cpython-310-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-310/Permutohedral_gpu.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-310/Permutohedral.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-310/PermutohedralFiltering/PermutohedralFiltering.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-310/PermutohedralFiltering/setup.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# copying build/lib.linux-x86_64-cpython-310/PermutohedralFiltering/__init__.py -> build/bdist.linux-x86_64/egg/PermutohedralFiltering
# creating build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-310/CRF/__init__.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-310/CRF/CRF.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-310/CRF/sparsemax.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-310/CRF/crfs_cpu.py -> build/bdist.linux-x86_64/egg/CRF
# copying build/lib.linux-x86_64-cpython-310/CRF/convcrf.py -> build/bdist.linux-x86_64/egg/CRF
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/PermutohedralFiltering.py to PermutohedralFiltering.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/setup.py to setup.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/PermutohedralFiltering/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/CRF.py to CRF.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/sparsemax.py to sparsemax.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/crfs_cpu.py to crfs_cpu.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CRF/convcrf.py to convcrf.cpython-310.pyc
# creating stub loader for Permutohedral.cpython-310-x86_64-linux-gnu.so
# creating stub loader for Permutohedral_gpu.cpython-310-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/Permutohedral.py to Permutohedral.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Permutohedral_gpu.py to Permutohedral_gpu.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/CRF.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# CRF.__pycache__.crfs_cpu.cpython-310: module references __file__
# __pycache__.Permutohedral.cpython-310: module references __file__
# __pycache__.Permutohedral_gpu.cpython-310: module references __file__
# creating dist
# creating 'dist/CRF-0.0.1-py3.10-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing CRF-0.0.1-py3.10-linux-x86_64.egg
# creating /usr/local/lib/python3.10/dist-packages/CRF-0.0.1-py3.10-linux-x86_64.egg
# Extracting CRF-0.0.1-py3.10-linux-x86_64.egg to /usr/local/lib/python3.10/dist-packages
# Adding CRF 0.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/CRF-0.0.1-py3.10-linux-x86_64.egg
# Processing dependencies for CRF==0.0.1
# Finished processing dependencies for CRF==0.0.1

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# ### ✅ Packages Handling

# %%
# @title  { display-mode: "form" }
# @markdown Useful packages.

import os
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR

# %%
# @title  { display-mode: "form" }
# @markdown User-defined packages.

from dataset import MicrographDataset, MicrographDatasetEvery
from dataset import reconstruct_patched
from model import create_model
from trainer import CryoEMEvaluator
from trainer import CryoEMTrainerWithScheduler, tqdm_plugin_for_Trainer

# %% [markdown]
# ## ⭐ Main

# %% [markdown]
# ### ✅ Setting

# %%
# @markdown Parameters.

NUM_CLASSES = 2
EPOCHS = 50
BATCH = 8
CROP_SIZE = (512, 512)
LR = 1e-3
RLR_PATIENCE = 3
ES_PATIENCE = 20
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# @markdown Set seed.

random_state = 42
torch.manual_seed(random_state)
torch.cuda.manual_seed_all(random_state)

# %% [markdown]
# ## ⭐ Convcrf wtih FCN finetuned on cryoem

# %% [markdown]
# ### ✅ Model

# %% [markdown]
# ## The model

# %%
# @title  { display-mode: "form" }

architecture = "Unet++" # @param {type:"string"}
encoder = "timm-efficientnet-b5" # @param {type:"string"}
pretrained = True # @param {type:"boolean"}
solver = "fw" # @param {type:"string"}
use_unary_only = True # @param {type:"boolean"}

# %%
import segmentation_models_pytorch as smp

if pretrained:
  weights = "imagenet"
else:
  weights = None

if architecture == "Unet++":
    backbone = smp.UnetPlusPlus(
        encoder_name=encoder,        # choose encoder, densenet201, resnet50, e.g. mobilenet_v2 or efficientnet-b5
        encoder_weights=weights,     # use `imagenet` or `advprop` for pre-trained weights for encoder initialization
        in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
        classes=2,                      # model output channels (number of classes in your dataset)
    )

elif architecture == "Deeplab":
    backbone = smp.DeepLabV3(
        encoder_name=encoder,        # choose encoder, densenet201, resnet50, e.g. mobilenet_v2 or efficientnet-b5
        encoder_weights=weights,     # use `imagenet` pre-trained weights for encoder initialization
        in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
        classes=2,                      # model output channels (number of classes in your dataset)
    )
else:
    print("Architecture not supported")
    raise NotImplementedError

model = create_model(backbone, addout=True) #crf_args
# Out:
# Downloading: "https://github.com/huggingface/pytorch-image-models/releases/download/v0.1-weights/tf_efficientnet_b5-c6949ce9.pth" to /root/.cache/torch/hub/checkpoints/tf_efficientnet_b5-c6949ce9.pth
# 100%|██████████| 117M/117M [00:00<00:00, 369MB/s]

# %%
import CRF
import torch.nn as nn
from model import setup_crf, create_fwcrf_model

# Example usage
solver = 'fw'  # Assuming the solver type is defined

crf = setup_crf(solver, NUM_CLASSES)
model_post = create_fwcrf_model(model.backbone, crf, use_unary_only=True)
# Out:
# CRF solver: fw
# x0_weight: 0.0
# FrankWolfeParams:
# 	 scheme:	 fixed
# 	 stepsize:	 1.0 (for the 'fixed' scheme)
# 	 regularizer:	 l2
# 	 lambda_:	 1.0
# 	 lambda_learnable:	 False
# 	 x0_weight:	 0.5
# 	 x0_weight_learnable:	 False
# Non-trainable lambda for Frank-Wolfe: 1.0
# Non-trainable x0_weight for Frank-Wolfe: 0.5
# Potts: remove random weights.
# Add 1.0 to spatial_weight diagonal
# Add 1.0 to bilateral_weight diagonal
# Add -1.0 to compatibility diagonal

# %% [markdown]
# ## ⭐ Evaluate

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

from torchvision.utils import save_image
from dataset import reconstruct_patched

def simple_micrograph_preprocessing(micrograph):
  micrograph_copy = micrograph.copy()
  micrograph_copy = (micrograph_copy-micrograph.mean()+2.5*micrograph.std())/5/micrograph.std()
  micrograph_copy[micrograph_copy<0]=0
  micrograph_copy[micrograph_copy>1]=1
  return micrograph_copy

# %%
from torch.utils.data import ConcatDataset

train_dir = os.path.join(IMAGE_DIR, 'train')
train_filenames = np.loadtxt(f"{IMAGE_DIR}/train_filenames.txt", dtype=str)
train_dataset =  MicrographDatasetEvery(image_dir=train_dir, label_dir=LABEL_DIR, filenames=train_filenames, crop_size=CROP_SIZE, crop=None)
train_loader = DataLoader(train_dataset , batch_size=None, shuffle=False, pin_memory=True)

val_dir = os.path.join(IMAGE_DIR, 'val')
val_filenames = np.loadtxt(f"{IMAGE_DIR}/val_filenames.txt", dtype=str)
val_dataset = MicrographDatasetEvery(image_dir=val_dir, label_dir=LABEL_DIR, filenames=val_filenames, crop_size=CROP_SIZE, crop=None)
val_loader = DataLoader(val_dataset, batch_size=None, shuffle=False, pin_memory=True)

test_dir = os.path.join(IMAGE_DIR, 'test')
test_filenames = np.loadtxt(f"{IMAGE_DIR}/test_filenames.txt", dtype=str)
test_dataset = MicrographDatasetEvery(image_dir=test_dir, label_dir=LABEL_DIR, filenames=test_filenames, crop_size=CROP_SIZE, crop=None)
test_loader = DataLoader(test_dataset, batch_size=None, shuffle=False, pin_memory=True)

full_filenames = np.concatenate((train_filenames, val_filenames, test_filenames))
full_dataset = ConcatDataset([train_dataset, val_dataset, test_dataset])
full_loader = DataLoader(full_dataset, batch_size=32, shuffle=True, pin_memory=True)

# %%
shape = None
for i1, i2, i3, i4 in val_loader: #test loader and reconstruct
    shape = i4.shape
    break

# %%
from PIL import Image

def normalize(im):
    max_mrc=np.max(im)
    min_mrc=np.min(im)
    img_original=(255*((im-min_mrc)/(max_mrc-min_mrc))).astype(np.uint8)
    return(img_original)

def preprocess_and_crop(micrograph, crop_size=3840):
    processed_micrograph = simple_micrograph_preprocessing(micrograph)
    if crop_size:
        mic_width, mic_height = processed_micrograph.shape[1], processed_micrograph.shape[0]
        start_x, start_y = (mic_width - crop_size) // 2, (mic_height - crop_size) // 2
        end_x, end_y = start_x + crop_size, start_y + crop_size
        return processed_micrograph[start_y:end_y, start_x:end_x]
    else:
        return processed_micrograph

# %%
from tqdm import tqdm

fnames = []
n = len(full_dataset)
processed_micrographs = np.empty((n, shape[1], shape[2]), dtype=np.float32)

# Use tqdm to wrap your loop for a progress bar
for idx, (test_image, _, grid, _) in tqdm(enumerate(full_dataset), total=n, desc="Processing images"):
    name = full_filenames[idx][:-4]
    fnames.append(name)
    # Determine the directory and load the micrograph
    if os.path.exists(f"{IMAGE_DIR}/test/{name}.npy"):
        micrograph_path = f"{IMAGE_DIR}/test/{name}.npy"
    elif os.path.exists(f"{IMAGE_DIR}/train/{name}.npy"):
        micrograph_path = f"{IMAGE_DIR}/train/{name}.npy"
    else:
        micrograph_path = f"{IMAGE_DIR}/val/{name}.npy"
    micrograph = np.load(micrograph_path)
    processed_micrograph = preprocess_and_crop(micrograph, crop_size=None)
    # Place the processed micrograph directly into the preallocated array
    processed_micrographs[idx] = processed_micrograph
# Out:
# Processing images:  48%|████▊     | 144/300 [03:26<04:19,  1.67s/it]

# %%
RESULT_DIR = "/content/drive/MyDrive/research_xs/results/10081_test/unet_eb5_dice_postcrf/" #model3

# %%
processed_micrographs.shape

# %%
np.save(f"{RESULT_DIR}/processed_micrographs.npy", processed_micrographs)

# %%
processed_micrographs = np.load(f"{RESULT_DIR}/processed_micrographs.npy")

# %%
del model
torch.cuda.empty_cache()

# %%
model = model_post

# %%
RESULT_DIR

# %%
import matplotlib.image as mpimg

# Load the image
mic = mpimg.imread('label_dir/Falcon_2012_06_12-15_07_41_0.png')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 12))  # Create two subplots side by side
# Plot on the first axis
ax1.imshow(mic, cmap='Greys_r')
ax1.set_title("Original Micrograph")

# Plot on the second axis (Zoomed-in area)
ax2.imshow(mic, cmap='gray')
ax2.set_xlim([2228, 3428])  # Set limits for x-axis
ax2.set_ylim([3328, 2128])  # Set limits for y-axis; inverted for typical image coordinate system
ax2.set_title("Zoomed-in View")

# %%
import torch.nn.functional as F

label_images = np.empty((0, shape[1], shape[2]), dtype=np.uint8)

checkpoint_paths = [path for path in os.listdir(RESULT_DIR) if '.pt' in path]
checkpoint_path = checkpoint_paths[-1]
state_dict_path = f"{RESULT_DIR}/{checkpoint_path}"
state_dict = torch.load(state_dict_path, map_location=torch.device(device))
model.load_state_dict(state_dict, strict=False)

model.to(device)
model.eval()

mini_batch_size = 18  # Number of patches to process at once
n = len(full_dataset)
label_images = np.empty((n, shape[1], shape[2]), dtype=np.uint8)  # Preallocated array

# Iterate through the dataset with tqdm for progress tracking
for idx, (test_image, _, grid, _) in tqdm(enumerate(full_dataset), total=n, desc="Processing dataset"):
    # Process in batches
    with torch.no_grad():
        inputs = test_image.to(device)
        num_batches = (inputs.size(0) + mini_batch_size - 1) // mini_batch_size
        patched_outputs = []

        for batch_idx in range(num_batches):
            start_idx = batch_idx * mini_batch_size
            end_idx = min(start_idx + mini_batch_size, inputs.size(0))
            patch_input = inputs[start_idx:end_idx].to(device)
            output = model(patch_input)['out']
            patched_outputs.append(output.cpu())  # Minimize device memory usage

            # Cleanup as soon as not needed
            del patch_input, output
            torch.cuda.empty_cache()

        outputs = torch.cat(patched_outputs)  # Combine outputs
        probabilities = F.softmax(outputs, dim=1)
        class1_probabilities = probabilities[:, 1, :, :]  # Assuming class 1 is the target
        pred_image = reconstruct_patched(class1_probabilities.unsqueeze(1), grid).float()
        output_image = normalize(pred_image.squeeze().numpy())

        # Cleanup large temporary variables
        del patched_outputs, outputs, probabilities, class1_probabilities, pred_image
        torch.cuda.empty_cache()

    # Store the output image directly in the preallocated array
    label_images[idx] = output_image

    if idx % 30 == 0:
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(output_image, cmap='inferno', alpha=0.4)
        plt.show()
    del output_image
    torch.cuda.empty_cache()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
np.save(f"{RESULT_DIR}/label_images.npy", label_images)

# %%
# !cp {RESULT_DIR}/label_images.npy .

# %%
label_images = np.load(f"{RESULT_DIR}/label_images.npy")

# %%
label_images.shape
# Out:
# (300, 3838, 3710)

# %%
# @title  { vertical-output: true, display-mode: "form" }
EMPIAR_ID = 10081 # @param {type:"integer"}
RADIUS = 77 # @param {type:"integer"}
# For 10017
BORDER = 0 # @param {type:"integer"}

# %% [markdown]
# ### Actual seg

# %%
radius = RADIUS

# %%
import skimage as ski
from skimage import img_as_float
from scipy import ndimage as ndi
from skimage import filters, segmentation, morphology
import itertools
import cv2


def min_rect_circle(cont):
    contours_poly = cv2.approxPolyDP(cont, 3, True)
    center, _= cv2.minEnclosingCircle(contours_poly)
    rect=cv2.minAreaRect(cont)
    box=np.int0(cv2.boxPoints(rect))
    mn,mx=np.amin(box,axis=0),np.amax(box,axis=0)
    diff=mx-mn
    if np.all(diff<(2*radius+40)):
        return(int(center[0]),int(center[1]))
    else:
        pass

def eliminate_near(fields):
    fields=np.array(fields,dtype=np.int32)
    i=np.arange(len(fields))
    diff=fields.reshape(len(fields),1,2)-fields
    D=np.sqrt((diff**2).sum(2))
    D=np.array(D,dtype=np.float64)
    D[np.triu_indices(D.shape[0])]=np.inf
    re = np.where(D< radius)
    out=np.array(list(zip(re[0],re[1])),dtype=np.int32)
    outmin=np.unique(np.min(out,axis=1))
    return(outmin)

def primary_sorting(i):
    #print("primary_sorting done")
    i1,i2,i3,i4=i[1]-(radius*2),i[0]-(radius*2),i[1]+(radius*2),i[0]+(radius*2)
    if i1<0 and i2<0:
        center=(i1+radius*2,i1+radius*2)
        i1=0
        i2=0
    elif i3 > thresh1.shape[0] and i4 > thresh1.shape[1]:
        i3= thresh1.shape[0]
        i4 = thresh1.shape[1]
        center=(radius*2,radius*2)
    elif i1<0:
        center=(i1+radius*2,i1+radius*2)
        i1=0
    elif i2<0:
        center=(i2+radius*2,i2+radius*2)
        i2=0
    elif i3 > thresh1.shape[0]:
        i3= thresh1.shape[0]
        center=(radius*2,radius*2)
    elif i4 > thresh1.shape[1]:
        i4 = thresh1.shape[1]
        center=(radius*2,radius*2)
    else:
        center=(radius*2,radius*2)


    th1=thresh1[i1:i3,i2:i4]

    c_frame=output_image[i1:i3,i2:i4]
    c_frame = cv2.cvtColor(c_frame, cv2.COLOR_GRAY2RGB)
    mask = np.zeros_like(th1)
    mask2 = np.zeros_like(th1)
    mask3 = np.zeros_like(c_frame)
    mask=cv2.circle(mask, center=center, radius=radius,color=(255),thickness=-1)
    mask2=cv2.circle(mask2, center=center, radius=radius+10,color=(255),thickness=-1)
    mask3=cv2.circle(mask3, center=center, radius=radius+10,color=[255,255,255],thickness=-1)
    col_mask= np.bitwise_and(c_frame,mask3)
    result = np.bitwise_and(th1,mask)
    result2 = np.bitwise_and(th1,mask2)
    col_a=np.where(np.all(col_mask== [0,255,0] , axis=-1))
    col_b=np.where(np.all(col_mask== [0,255,255] , axis=-1))
    inn_positions=np.nonzero(result)
    out_positions=np.nonzero(result2)

    contours, hierarchy = cv2.findContours(result,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    l=len(contours)
    a,b= (inn_positions[0].max()-inn_positions[0].min()),(inn_positions[1].max()-inn_positions[1].min())
    c,d= (out_positions[0].max()-out_positions[0].min()),(out_positions[1].max()-out_positions[1].min())
    if (len(col_a[0]) or len(col_b[0]))>0 :
        pass
    elif (c or d) > (radius*2.1):
        pass
    elif l==1 and ((c and d) <(radius*2)):
        return(tuple([i[0],i[1]]))
    else:

        #cv2.circle(frame, i, radius, (255, 0, 0), 3)
        ans={}
        centerx=range(0+radius,th1.shape[1]-radius,5)
        centery=range(0+radius,th1.shape[0]-radius,5)
        rad=range(radius,5,5)
        for cx,cy in itertools.product(centerx,centery):
            mask00 = np.zeros_like(th1)
            mask20=mask.copy()
            mask00=cv2.circle(mask00, center=(cx,cy), radius=radius, color=(255,255,255), thickness=-1)
            mask20=cv2.circle(mask20, center=(cx,cy), radius=radius+5, color=(255,255,255), thickness=-1)
            result00 = np.bitwise_and(th1,mask00)
            tot_ellip=np.sum(mask00 == [255])
            tot_ellip_white1=np.sum(result00 == [255])
            per_white=(tot_ellip_white1/tot_ellip)*100
            result002 = np.bitwise_and(th1,mask20)
            tot_ellip_white2=np.sum(result002 == [255])
            diff=tot_ellip_white2-tot_ellip_white1

            if diff<10 and per_white>10:
                ans[per_white]=(cx,cy)


        if len(ans.keys())>0:
            k=ans[max(ans.keys())]
            return (tuple([i2+k[0],i1+k[1]]))
        else:
            pass

# %%
BORDER
# Out:
# 0

# %%
from skimage import img_as_float
from skimage.filters import threshold_local

cv_list = []
for img in label_images:
    output_image = img_as_float(img)
    block_size = int(round(radius * 1.6)) | 1  # Ensure it's an odd number
    local_thresh = filters.threshold_local(output_image, block_size, method='gaussian', offset=0)
    image_seg = output_image > local_thresh
    thresh1 = ski.util.img_as_ubyte(image_seg)

    contr_min = radius*0.6
    kernel_size = int(radius / 2)  # Example ratio
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    thresh1 = cv2.erode(thresh1, kernel, iterations=1)

    contours, hierarchy = cv2.findContours(thresh1,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cont_array = [c for c in contours]

    # Filter out small/large region and find bounding box with center
    c_ = np.array([cv2.contourArea(contour) for contour in contours])
    aa = (c_>contr_min) & (c_<500000)
    aa = aa.tolist()
    c_full_list = [d for d, keep in zip(cont_array, aa) if keep]
    c_list = (list(map(lambda x: min_rect_circle(x), c_full_list)))
    c_list = [x for x in c_list if x is not None]
    cv_list.append(c_list)
    print(len(c_full_list), len(c_list))
# Out:
# <ipython-input-57-7d9b2ef565d5>:13: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box=np.int0(cv2.boxPoints(rect))
# 94 93
# 49 49
# 13 13
# 144 144
# 163 159
# 146 144
# 152 148
# 197 190
# 258 249
# 185 183
# 163 158
# 167 165
# 153 149
# 139 136
# 198 193
# 223 217
# 255 239
# 173 170
# 144 142
# 139 136
# 139 136
# 193 187
# 173 172
# 106 105
# 97 96
# 151 146
# 160 154
# 152 151
# 97 96
# 142 140
# 98 95
# 125 125
# 104 104
# 279 271
# 160 156
# 173 168
# 113 112
# 137 136
# 100 99
# 115 115
# 102 102
# 123 120
# 121 117
# 174 171
# 183 179
# 92 92
# 92 91
# 54 54
# 98 97
# 88 88
# 70 69
# 18 18
# 110 110
# 45 45
# 31 31
# 66 66
# 58 58
# 28 28
# 100 100
# 105 105
# 57 57
# 85 85
# 43 43
# 75 73
# 38 38
# 61 60
# 76 76
# 82 82
# 135 134
# 115 114
# 79 78
# 69 69
# 75 75
# 55 53
# 0 0
# 3 3
# 36 36
# 35 35
# 116 116
# 62 61
# 88 87
# 35 35
# 66 66
# 80 80
# 88 88
# 56 55
# 64 64
# 155 153
# 169 168
# 19 19
# 35 35
# 13 13
# 197 193
# 162 158
# 167 165
# 190 182
# 147 144
# 189 188
# 149 147
# 170 168
# 181 181
# 157 155
# 105 103
# 144 144
# 159 158
# 144 143
# 176 173
# 188 185
# 166 164
# 134 133
# 126 125
# 172 169
# 137 135
# 149 147
# 126 123
# 154 153
# 176 173
# 168 167
# 176 175
# 143 141
# 164 163
# 155 152
# 145 143
# 201 194
# 243 236
# 175 172
# 200 196
# 148 144
# 160 158
# 154 152
# 193 193
# 225 219
# 230 219
# 228 224
# 253 236
# 217 217
# 200 191
# 233 225
# 177 170
# 242 227
# 270 259
# 246 226
# 250 240
# 268 251
# 242 234
# 232 219
# 253 244
# 226 217
# 211 206
# 216 211
# 204 200
# 242 238
# 143 140
# 193 189
# 142 141
# 155 152
# 160 158
# 149 148
# 166 165
# 142 138
# 159 156
# 147 142
# 133 133
# 171 167
# 171 169
# 158 155
# 139 138
# 166 164
# 220 215
# 174 171
# 212 207
# 216 206
# 177 177
# 172 172
# 173 171
# 217 213
# 128 127
# 181 178
# 175 167
# 170 164
# 195 188
# 169 166
# 187 181
# 180 176
# 153 150
# 190 186
# 206 202
# 179 176
# 155 153
# 174 169
# 190 186
# 124 124
# 107 105
# 90 90
# 117 116
# 138 138
# 84 84
# 144 143
# 123 122
# 131 130
# 141 140
# 86 86
# 141 140
# 85 85
# 97 97
# 129 128
# 139 139
# 143 139
# 144 142
# 157 154
# 191 189
# 143 142
# 129 128
# 162 158
# 128 127
# 113 112
# 109 109
# 116 113
# 157 156
# 142 141
# 123 122
# 133 132
# 134 133
# 200 196
# 148 147
# 143 142
# 126 125
# 161 158
# 118 118
# 114 112
# 108 106
# 158 158
# 129 123
# 122 122
# 122 118
# 138 137
# 142 140
# 134 133
# 223 218
# 258 249
# 237 230
# 234 223
# 215 208
# 251 234
# 228 222
# 111 110
# 87 85
# 49 49
# 89 88
# 79 79
# 69 69
# 59 59
# 109 107
# 108 107
# 140 139
# 143 141
# 121 119
# 127 126
# 181 180
# 172 170
# 184 182
# 177 174
# 228 221
# 233 230
# 189 187
# 171 168
# 178 175
# 188 184
# 237 233
# 210 208
# 160 157
# 167 165
# 143 143
# 161 160
# 149 149
# 128 126
# 137 135
# 169 164
# 91 91
# 202 194
# 163 160
# 181 176
# 189 185
# 113 112
# 148 145
# 158 152
# 219 215
# 209 203
# 223 217
# 200 196
# 185 174
# 155 150
# 174 165
# 209 202
# 284 276
# 196 191
# 217 214
# 215 201
# 259 242
# 227 222

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    #if idx == 6:
    #    break
    if idx % 30 == 0:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in cv_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install starfile -qq

# %%
# !cp /content/drive/MyDrive/research_xs/dataset/{EMPIAR_ID}/ground_truth/empiar-{EMPIAR_ID}_particles_selected.star .

# %%
import starfile
optics, df = starfile.read(f"empiar-{EMPIAR_ID}_particles_selected.star")['optics'], starfile.read(f"empiar-{EMPIAR_ID}_particles_selected.star")['particles']
df
# Out:
#                                             rlnImageName  \
# 0      000001@>J16/extract/HCN1apo_0183_2xaligned_par...
# 1      000002@>J16/extract/HCN1apo_0183_2xaligned_par...
# 2      000003@>J16/extract/HCN1apo_0183_2xaligned_par...
# 3      000004@>J16/extract/HCN1apo_0183_2xaligned_par...
# 4      000005@>J16/extract/HCN1apo_0183_2xaligned_par...
# ...                                                  ...
# 39347  000179@>J16/extract/HCN1apo_0686_2xaligned_par...
# 39348  000180@>J16/extract/HCN1apo_0686_2xaligned_par...
# 39349  000182@>J16/extract/HCN1apo_0686_2xaligned_par...
# 39350  000183@>J16/extract/HCN1apo_0686_2xaligned_par...
# 39351  000186@>J16/extract/HCN1apo_0686_2xaligned_par...
#
#                                        rlnMicrographName  rlnCoordinateX  \
# 0      >J1/imported/000008714401408334489_HCN1apo_018...            2041
# 1      >J1/imported/000008714401408334489_HCN1apo_018...             985
# 2      >J1/imported/000008714401408334489_HCN1apo_018...            2258
# 3      >J1/imported/000008714401408334489_HCN1apo_018...            1529
# 4      >J1/imported/000008714401408334489_HCN1apo_018...            3416
# ...                                                  ...             ...
# 39347  >J1/imported/018401356561406588198_HCN1apo_068...            1861
# 39348  >J1/imported/018401356561406588198_HCN1apo_068...             966
# 39349  >J1/imported/018401356561406588198_HCN1apo_068...            2316
# 39350  >J1/imported/018401356561406588198_HCN1apo_068...            2047
# 39351  >J1/imported/018401356561406588198_HCN1apo_068...             908
#
#        rlnCoordinateY  rlnAnglePsi  rlnOriginXAngst  rlnOriginYAngst  \
# 0                 384   349.897949        -0.422500        -1.267500
# 1                2821   103.775505         1.267500        -2.112500
# 2                2066    57.857143        -0.422500         2.112500
# 3                 620   276.428558        -1.267500        -2.112500
# 4                 256   283.775482        -0.422500        -0.422500
# ...               ...          ...              ...              ...
# 39347             134    26.632650        -3.802500        14.787499
# 39348            2712   302.142822        12.252500        -9.717500
# 39349            2847   173.571426        13.942500         8.027500
# 39350            1682   112.959175       -11.407499       -14.787499
# 39351            3448    26.632650        -8.027500        12.252500
#
#         rlnDefocusU   rlnDefocusV  rlnDefocusAngle  rlnPhaseShift  \
# 0      18693.681641  17792.365234       -75.985649            0.0
# 1      18627.705078  17726.388672       -75.985649            0.0
# 2      18799.509766  17898.193359       -75.985649            0.0
# 3      18722.833984  17821.517578       -75.985649            0.0
# 4      18868.507812  17967.191406       -75.985649            0.0
# ...             ...           ...              ...            ...
# 39347  21976.574219  20989.371094       -75.429733            0.0
# 39348  22019.349609  21032.146484       -75.429733            0.0
# 39349  21821.414062  20834.210938       -75.429733            0.0
# 39350  21797.146484  20809.943359       -75.429733            0.0
# 39351  21968.212891  20981.009766       -75.429733            0.0
#
#        rlnCtfBfactor  rlnOpticsGroup  rlnClassNumber
# 0                0.0               1              38
# 1                0.0               1              38
# 2                0.0               1              38
# 3                0.0               1              38
# 4                0.0               1              38
# ...              ...             ...             ...
# 39347            0.0               1              20
# 39348            0.0               1              37
# 39349            0.0               1              48
# 39350            0.0               1              46
# 39351            0.0               1              49
#
# [39352 rows x 14 columns]

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in cv_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#       rlnCoordinateX rlnCoordinateY                      rlnImageName  \
# 0                729           3777  00000@HCN1apo_0030_2xaligned.mrc
# 1               1421           3764  00001@HCN1apo_0030_2xaligned.mrc
# 2                517           3690  00002@HCN1apo_0030_2xaligned.mrc
# 3               2489           3690  00003@HCN1apo_0030_2xaligned.mrc
# 4                739           3585  00004@HCN1apo_0030_2xaligned.mrc
# ...              ...            ...                               ...
# 43807            604             62  00217@HCN1apo_1060_2xaligned.mrc
# 43808           3125             55  00218@HCN1apo_1060_2xaligned.mrc
# 43809           1830             60  00219@HCN1apo_1060_2xaligned.mrc
# 43810           3361            106  00220@HCN1apo_1060_2xaligned.mrc
# 43811           3239             35  00221@HCN1apo_1060_2xaligned.mrc
#
#                 rlnMicrographName
# 0      HCN1apo_0030_2xaligned.mrc
# 1      HCN1apo_0030_2xaligned.mrc
# 2      HCN1apo_0030_2xaligned.mrc
# 3      HCN1apo_0030_2xaligned.mrc
# 4      HCN1apo_0030_2xaligned.mrc
# ...                           ...
# 43807  HCN1apo_1060_2xaligned.mrc
# 43808  HCN1apo_1060_2xaligned.mrc
# 43809  HCN1apo_1060_2xaligned.mrc
# 43810  HCN1apo_1060_2xaligned.mrc
# 43811  HCN1apo_1060_2xaligned.mrc
#
# [43812 rows x 4 columns]

# %%
starfile.write(df, f'{RESULT_DIR}/cv_particles.star')

# %% [markdown]
# ### TrackPy

# %%
import trackpy as tp

# %%
TrackParticleSize = 153
curr_adpmass = 0
sep = 61
scale = 0.25  # Scale factor (0.5 means reducing the size to half)

# %%
tp_list = []
for img in label_images:
    output_image = img
    small_image = cv2.resize(output_image, None, fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
    # Adjust parameters based on the scale
    small_sep = int(sep * scale)
    small_diameter = int(TrackParticleSize * scale)
    if small_diameter % 2 == 0:
        small_diameter += 1
    coorTrack = tp.locate(small_image, diameter=small_diameter, minmass=curr_adpmass, separation=small_sep)
    #coorTrack.loc[:,'prob']=[output_image[getattr(coor,'y'),getattr(coor,'x')] for coor in np.floor(coorTrack[['x','y']]).astype('int').itertuples()]
    coorTrack['x'] *= (1/scale)
    coorTrack['y'] *= (1/scale)
    coords = coorTrack[['x', 'y']].values
    tp_list.append(coords)
    print(len(coords))
# Out:
# 90
# 44
# 12
# 142
# 161
# 156
# 160
# 208
# 275
# 195
# 166
# 164
# 153
# 134
# 198
# 232
# 282
# 168
# 143
# 157
# 156
# 187
# 177
# 107
# 98
# 144
# 169
# 154
# 98
# 147
# 98
# 126
# 106
# 292
# 165
# 176
# 114
# 133
# 104
# 117
# 106
# 119
# 130
# 185
# 189
# 92
# 94
# 58
# 96
# 85
# 73
# 23
# 107
# 50
# 31
# 66
# 52
# 36
# 98
# 104
# 61
# 83
# 43
# 70
# 36
# 63
# 75
# 78
# 132
# 120
# 78
# 63
# 74
# 57
# 9
# 6
# 30
# 31
# 113
# 62
# 86
# 35
# 66
# 81
# 89
# 57
# 59
# 152
# 158
# 20
# 30
# 20
# 198
# 170
# 166
# 194
# 149
# 183
# 152
# 180
# 179
# 158
# 111
# 141
# 162
# 144
# 173
# 182
# 157
# 132
# 127
# 169
# 144
# 156
# 128
# 151
# 175
# 166
# 193
# 141
# 164
# 161
# 149
# 206
# 254
# 182
# 202
# 149
# 168
# 157
# 194
# 239
# 250
# 228
# 258
# 238
# 217
# 255
# 184
# 263
# 283
# 262
# 272
# 299
# 280
# 253
# 254
# 245
# 207
# 225
# 206
# 237
# 152
# 207
# 149
# 155
# 157
# 156
# 168
# 146
# 160
# 153
# 131
# 172
# 183
# 157
# 145
# 170
# 217
# 176
# 216
# 232
# 178
# 173
# 176
# 226
# 134
# 184
# 191
# 175
# 216
# 179
# 187
# 188
# 163
# 189
# 201
# 178
# 164
# 181
# 202
# 125
# 105
# 101
# 116
# 140
# 88
# 150
# 129
# 145
# 143
# 85
# 144
# 83
# 101
# 131
# 138
# 144
# 145
# 155
# 206
# 144
# 123
# 160
# 119
# 112
# 115
# 124
# 151
# 153
# 129
# 131
# 129
# 205
# 149
# 141
# 131
# 161
# 112
# 118
# 101
# 154
# 141
# 114
# 123
# 146
# 141
# 139
# 247
# 283
# 244
# 259
# 230
# 272
# 234
# 112
# 88
# 47
# 89
# 75
# 65
# 56
# 108
# 109
# 151
# 154
# 129
# 145
# 184
# 174
# 194
# 184
# 241
# 241
# 195
# 181
# 185
# 188
# 247
# 206
# 170
# 171
# 143
# 167
# 153
# 136
# 138
# 177
# 90
# 205
# 167
# 178
# 199
# 114
# 159
# 168
# 215
# 220
# 241
# 209
# 204
# 167
# 173
# 235
# 294
# 206
# 225
# 244
# 273
# 217

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    # if idx == 6:
    #     break
    if idx % 30 == 0:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in tp_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in tp_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#        rlnCoordinateX  rlnCoordinateY                      rlnImageName  \
# 0         1129.319838      106.044009  00000@HCN1apo_0030_2xaligned.mrc
# 1          429.396330      131.435529  00001@HCN1apo_0030_2xaligned.mrc
# 2         3231.505852      166.323780  00002@HCN1apo_0030_2xaligned.mrc
# 3         1205.192377      165.609999  00003@HCN1apo_0030_2xaligned.mrc
# 4         3469.696527      295.035429  00004@HCN1apo_0030_2xaligned.mrc
# ...               ...             ...                               ...
# 45958     3011.966549     3721.648035  00212@HCN1apo_1060_2xaligned.mrc
# 45959     2875.534449     3692.463562  00213@HCN1apo_1060_2xaligned.mrc
# 45960      943.195842     3740.767483  00214@HCN1apo_1060_2xaligned.mrc
# 45961      410.545901     3762.503888  00215@HCN1apo_1060_2xaligned.mrc
# 45962     3164.336137     3787.866052  00216@HCN1apo_1060_2xaligned.mrc
#
#                 rlnMicrographName
# 0      HCN1apo_0030_2xaligned.mrc
# 1      HCN1apo_0030_2xaligned.mrc
# 2      HCN1apo_0030_2xaligned.mrc
# 3      HCN1apo_0030_2xaligned.mrc
# 4      HCN1apo_0030_2xaligned.mrc
# ...                           ...
# 45958  HCN1apo_1060_2xaligned.mrc
# 45959  HCN1apo_1060_2xaligned.mrc
# 45960  HCN1apo_1060_2xaligned.mrc
# 45961  HCN1apo_1060_2xaligned.mrc
# 45962  HCN1apo_1060_2xaligned.mrc
#
# [45963 rows x 4 columns]

# %%
import starfile
starfile.write(df, f'{RESULT_DIR}/tp_particles.star')

# %% [markdown]
# ### Nonmax

# %%
#ratio=1
pnum=1000 #initial filtering, larger if candidate is more
pCan=0.4 #the grid size smaller will generate more candidate
overlap=0.6 #allow for overlap
psize=RADIUS*2

# Nor affect too much
level=3
nSep=10
nIter=100

# %%
import pycuda.driver as drv
from pycuda.compiler import SourceModule
import pycuda.autoinit  # Automatically initializes CUDA, creates a context which is needed
import cv2

mod = SourceModule("""
__global__ void scoreGpu(float* heat,float*gaus, float*score, int sizex, int sizey, int psize)
{
    // 2D Thread ID (assuming that only *one* block will be executed)
    int tx=threadIdx.x;
    int ty=threadIdx.y;

    tx=blockIdx.x*blockDim.x+tx;
    ty=blockIdx.y*blockDim.y+ty;

    int tmp=psize/2;
    if((tx >= tmp) && (ty >= tmp) && (tx <= sizex-tmp) && (ty < sizey-tmp) ){
        int sx=tx-tmp;
        int sy=ty-tmp;
        heat=heat+sx*sizex+sy;
        //heat=heat+tx*sizex+ty;
        float sum=0;
        int sub=0;
        for(int i=0;i<psize;i++){
            for(int j=0;j<psize;j++){
                sum=sum+gaus[sub]*heat[j];
                sub=sub+1;
            }
            heat=heat+sizex;
        }
        score[tx*sizex+ty]=sum;

    }//end if
}
__global__ void getMax(float* score, float* list, int size, int sizex, int sizey, int numx){
    int tx=threadIdx.x;
    int ty=threadIdx.y;

    tx=blockIdx.x*blockDim.x+tx;
    ty=blockIdx.y*blockDim.y+ty;
    int cx=tx*size;
    int cy=ty*size;


    if(cx<sizex&&cy<sizey){
        int sx=size;
        int sy=size;

        if(cx+size>sizex){
            sx=sizex-cx;
        }
        if(cy+size>sizey){
            sy=sizey-cy;
        }
        score=score+cx*sizex+cy;
        //float max=6.805646932770577*(1000000000000000000000);
        float max=0;
        int maxx=0;
        int maxy=0;
        for(int i=0;i<sx;i++){
            for(int j=0;j<sy;j++){
                if(score[j]>=max){
                    max=score[j];
                    maxx=cx+i;
                    maxy=cy+j;
                }
            }
            score=score+sizex;
        }

        int sub=5*(tx*numx+ty);
        list[sub]=maxx;
        list[sub+1]=maxy;
        list[sub+2]=max;
        list[sub+3]=tx;
        list[sub+4]=ty;
    }
}

__global__ void getMax3(float* score, float* list, int psize, int sizex, int sizey, int numx,int num, int iter){
    int tx=threadIdx.x;
    int ty=threadIdx.y;

    tx=blockIdx.x*blockDim.x+tx;
    ty=blockIdx.y*blockDim.y+ty;
    int sub=(tx*numx+ty)*5;

    if (sub<num){
        int cx=list[sub]-psize/2;
        int cy=list[sub+1]-psize/2;

        float max=0;
        int maxx=0;
        int maxy=0;

        for(int i=0;i<iter;i++){

            if(cx<sizex&&cy<sizey&&cx>0&&cy>0){
                int sx=psize;
                int sy=psize;

                if(cx+sx>sizex){
                    sx=sizex-cx;
                }
                if(cy+sy>sizey){
                    sy=sizey-cy;
                }
                max=0;
                maxx=0;
                maxy=0;
                float* score0=score+cx*sizex+cy;
                for(int i=0;i<sx;i++){
                    for(int j=0;j<sy;j++){
                        if(score0[j]>=max){
                            max=score0[j];
                            maxx=cx+i;
                            maxy=cy+j;
                        }
                    }
                    score0=score0+sizex;
                }
                cx=maxx-psize/2;
                cy=maxy-psize/2;
            }
         }//end for

        list[sub]=maxx;
        list[sub+1]=maxy;
        list[sub+2]=max;
        list[sub+3]=tx;
        list[sub+4]=ty;
    }//end if num
}



__global__ void multiply_them(float *dest, float *a, float *b)
{
  const int i = threadIdx.x;
  dest[i] = a[i] * b[i];
}

""")

class item:
    def __init__(self,count=0,x=0 ,y=0 ):
        self.id=count
        self.minX = x
        self.minY=y
        self.maxX=x
        self.maxY=y
        self.totalN=0
        self.totalS=0
        self.x=x
        self.y=y
        self.p=0.1
    def __str__(self):
        line=str(self.id)+' '+str(self.minX)+' '+str(self.maxX)+' '+str(self.minY)+' '+str(self.maxY) \
                +' '+str(self.totalN)+' '+str(self.totalS)+' '+str(self.x)+' '+str(self.y)+' '+str(self.p)+'\n'
        return line

    def update(self,x,y):
        if(x<self.minX):
            self.minX=x
        elif(x>self.maxX):
            self.maxX=x

        if(y<self.minY):
            self.minY=y
        elif(y>self.maxY):
            self.maxY=y

        self.totalN=self.totalN+1

        return self

    def getS(self):
        width=self.maxX-self.minX+1
        length=self.maxY-self.minY+1
        self.totalS=width*length
        self.x=self.minX+width/2
        self.y=self.minY+width/2
        self.p=float(self.totalN)/self.totalS
        return self.totalS

def reshape(res,num):
    canList=[]
    for i in range(0,num):
        sub=i*5
        m=res[sub+2]
        if m!=0:
            candi=[int(res[sub]),int(res[sub+1]),m,int(res[sub+2]),int(res[sub+3])]
            canList.append(candi)
    print('convert')
    canList.sort(key=lambda x: x[2], reverse=True)

    #for i in range(0, 10):
    #    print(canList[i])
    return canList

def gaussian_kernel_2d_opencv(kernel_size = 3,sigma = 1):
    kx = cv2.getGaussianKernel(kernel_size,sigma)
    ky = cv2.getGaussianKernel(kernel_size,sigma)
    res=np.multiply(kx,np.transpose(ky))
    res=1-(res-np.max(res))/(-1*np.ptp(res))
    return res

def getOverlap(x,y,rx,ry,p):
    t=int(p/2)
    xmin=x-t
    xmax=x+t
    ymin=y-t
    ymax=y+t

    rxmin=rx-t
    rxmax=rx+t
    rymin=ry-t
    rymax=ry+t

    x1=abs(rxmin-xmax)
    x2=abs(rxmax-xmin)
    lx=min(x1,x2)

    y1=abs(rymin-ymax)
    y2=abs(rymax-ymin)
    ly=min(y1,y2)

    return lx*ly

def cleanCanList(canList,op1,psize):
    numCan=len(canList)
    op=op1*psize*psize
    tmp=[-psize,-psize,0]
    for i in range(0,len(canList)):
        candi=canList[i]
        if candi !=tmp:
            x=candi[0]
            y=candi[1]

            for j in range(i+1,len(canList)) :
                candi=canList[j]
                rx=candi[0]
                ry=candi[1]

                if abs(x-rx)<psize and abs(y-ry)<psize:
                    sOp=getOverlap(x,y,rx,ry,psize)
                    if sOp>op:
                        #print(rx,ry,sOp,op)
                        canList[j]=tmp #delete
                        (canList[i])[0]=0.8*x+0.2*rx
                        (canList[i])[1]=0.8*y+0.2*ry


    return [x for x in canList if x != tmp]

def writeStarHead(fstar):
    star=open(fstar,'w')
    star.write('data_\n\n')
    star.write('loop_\n')
    star.write('_rlnCoordinateX #1\n')
    star.write('_rlnCoordinateY #2\n')
    star.write('_rlnParticleSelectZScore  #3\n')
    return star

def writeCan(fstar,canList,sizex, sizey):
    fstar=writeStarHead(fstar)
    p=0
    l=len(canList)
    for i in range(0,l):
        c=canList[i]
        #line=str(c[0])+' '+str(c[1])+' '+str(c[2])+'\n'
        #x=c[1]
        #y=sizey-c[0]
        x=c[0]
        y=c[1]
        x0=y
        y0=x
        if(len(c)>2):
            p=c[2]

        line=str(x0)+' '+str(y0)+' '+str(p)+'\n'
        #print(line)
        fstar.write(line)
    fstar.close()

def reNorm(heatArr, nSep):
    ksize=5

    kernel = np.ones((ksize,ksize),np.uint8)
    img = cv2.erode(heatArr,kernel,iterations = nSep)
    #tmp=int(psize/4)
    #if tmp%2 ==0:
    #    tmp=tmp+1
    #heatArr= cv2.medianBlur(heatArr,tmp)
    #heatArr= cv2.medianBlur(heatArr,5)
    #heatArr= cv2.medianBlur(heatArr,5)
    #heatArr= cv2.medianBlur(heatArr,5)
    return heatArr

def reLev(heatArr, level):
    num=int(255/level)
    heatArr=heatArr/num
    heatArr=heatArr.astype(int)
    return heatArr

def draw(im, cx, cy, sx, sy):
    # Calculate rectangle coordinates
    startx = int(cx - sx / 2)
    starty = int(cy - sy / 2)  # Corrected to use sy
    endx = int(cx + sx / 2)
    endy = int(cy + sy / 2)

    # Calculate colors (simplified for demonstration; adjust as necessary)
    c = 1
    r = (c // 4) * 255
    g = ((c % 4) // 2) * 255
    b = (c % 2) * 255

    # Thickness of the rectangle border
    w = 2

    # Draw the rectangle
    cv2.rectangle(im, (startx, starty), (endx, endy), (b, g, r), w)

    return im

def checkScore(score):
    score0=np.zeros([score.shape[0], score.shape[1],3])
    print(score0.shape, score.shape)
    score0[:,:,0]=score[:,:]
    score0[:,:,1]=score[:,:]
    score0[:,:,2]=score[:,:]
    a=score0
    score0=(255*(a - np.max(a))/-np.ptp(a))
    for c in canList:
        x=int(c[0])
        y=int(c[1])
        sx=sy=psize
        score0=draw(score0,x,y,sx,sy)

def pad_image(image_array):
    # Get the current height and width of the image
    height, width = image_array.shape

    # Find the smallest pixel value in the image to use as padding value
    min_pixel_value = np.min(image_array)

    # Determine the size of padding needed
    if height > width:
        diff = height - width
        padding = ((0, 0), (0, diff))  # Padding only to the right
    else:
        diff = width - height
        padding = ((0, diff), (0, 0))  # Padding only to the bottom

    # Apply padding, using the smallest pixel value found
    padded_image = np.pad(image_array, padding, mode='constant', constant_values=min_pixel_value)
    return padded_image

# %%
nms_list = []
for idx, img in enumerate(label_images):
    # if idx == 6:
    #     break
    heatArr=pad_image(img)
    heatArr=reNorm(heatArr, nSep)
    heatArr=reLev(heatArr,level)
    gaus= gaussian_kernel_2d_opencv(kernel_size = psize,sigma = 0)

    # canList,score=scoreGpuLaunch(heatArr,gaus,psize, gsize, nIter, fscore)
    gsize=psize*pCan
    heat=heatArr.astype(np.float32)
    gaus=gaus.astype(np.float32)
    score=np.zeros(heat.shape).astype(np.float32)
    [sizex,sizey]=heat.shape
    sizex = int(sizex)
    sizey = int(sizey)
    psize = int(psize)
    gsize = int(gsize)

    func = mod.get_function("scoreGpu")

    tx=16
    ty=16
    bx=(sizex-1)//tx+1
    by=(sizey-1)//ty+1
    print('get score gpu',tx, ty, bx, by, gsize, psize)


    func(drv.In(heat), drv.In(gaus), drv.Out(score), np.int32(sizex), np.int32(sizey), np.int32(psize),
        block=(tx, ty, 1), grid=(int(bx), int(by)))

    # # Calculate necessary dimensions and convert all to int
    numx = int((sizex - 1) // gsize + 1)
    numy = int((sizey - 1) // gsize + 1)
    num = numx * numy
    tnum = num * 5

    # # Create the result array
    res = np.zeros(tnum).astype(np.float32)

    # # Block and grid dimensions
    bx = (numx - 1) // tx + 1
    by = (numy - 1) // ty + 1

    # Get the function from the module
    func = mod.get_function("getMax")

    # Call the function, ensure all parameters are the correct type
    func(drv.In(score), drv.Out(res), np.int32(gsize), np.int32(sizex), np.int32(sizey), np.int32(numx),
        block=(16, 16, 1), grid=(bx, by, 1))

    # Make sure all dimensions and sizes are properly cast to np.int32 to avoid ambiguity
    niter = np.int32(nIter)
    gsize = np.int32(gsize)
    sizex = np.int32(sizex)
    sizey = np.int32(sizey)
    numx = np.int32(numx)
    tnum = np.int32(num)

    print('get Max3', tx, ty, bx, by, niter, 'other : ', gsize, sizex, sizey, numx, tnum)
    func = mod.get_function("getMax3")
    # Ensuring the correct parameter order and type for the kernel invocation
    func(drv.In(score), drv.InOut(res), gsize, sizex, sizey, numx, tnum, niter,
            block=(16, 16, 1), grid=(bx, by, 1))

    canList=reshape(res,num)

    print('Number of Particles before:', len(canList))
    if(len(canList)>pnum):
        canList=canList[:pnum]


    canList=cleanCanList(canList,overlap,psize)
    #canList=reCan(canList,ratio)
    print('Number of Particles:', len(canList))
    nms_list.append([(r[1],r[0]) for r in canList])
# Out:
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2347
# Number of Particles: 92
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1444
# Number of Particles: 173
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 573
# Number of Particles: 97
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2914
# Number of Particles: 132
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3044
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3076
# Number of Particles: 150
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3006
# Number of Particles: 150
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3293
# Number of Particles: 180
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3629
# Number of Particles: 229
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3310
# Number of Particles: 175
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3150
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3046
# Number of Particles: 154
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2995
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2901
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3362
# Number of Particles: 174
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3511
# Number of Particles: 178
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3635
# Number of Particles: 221
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3125
# Number of Particles: 162
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2975
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2961
# Number of Particles: 138
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2993
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3247
# Number of Particles: 166
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3089
# Number of Particles: 156
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2563
# Number of Particles: 108
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2429
# Number of Particles: 96
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2934
# Number of Particles: 140
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3103
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3111
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2398
# Number of Particles: 97
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2958
# Number of Particles: 144
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2430
# Number of Particles: 100
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2783
# Number of Particles: 123
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2548
# Number of Particles: 101
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3603
# Number of Particles: 234
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3057
# Number of Particles: 145
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3183
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2696
# Number of Particles: 111
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2883
# Number of Particles: 127
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2588
# Number of Particles: 99
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2593
# Number of Particles: 117
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2615
# Number of Particles: 101
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2689
# Number of Particles: 118
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2702
# Number of Particles: 125
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3163
# Number of Particles: 166
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3217
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2460
# Number of Particles: 95
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2328
# Number of Particles: 93
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2050
# Number of Particles: 70
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2451
# Number of Particles: 97
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2323
# Number of Particles: 89
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2027
# Number of Particles: 133
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1107
# Number of Particles: 168
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2522
# Number of Particles: 106
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1764
# Number of Particles: 113
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1333
# Number of Particles: 143
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2090
# Number of Particles: 96
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1864
# Number of Particles: 119
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1318
# Number of Particles: 134
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2369
# Number of Particles: 99
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2513
# Number of Particles: 107
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1782
# Number of Particles: 120
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2267
# Number of Particles: 85
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1574
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2088
# Number of Particles: 92
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1285
# Number of Particles: 166
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1730
# Number of Particles: 208
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2121
# Number of Particles: 80
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2179
# Number of Particles: 86
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2801
# Number of Particles: 124
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2846
# Number of Particles: 121
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2098
# Number of Particles: 82
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2001
# Number of Particles: 118
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2028
# Number of Particles: 136
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1452
# Number of Particles: 172
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 679
# Number of Particles: 71
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 681
# Number of Particles: 65
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1141
# Number of Particles: 187
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 708
# Number of Particles: 237
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2592
# Number of Particles: 114
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1660
# Number of Particles: 221
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2261
# Number of Particles: 106
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1104
# Number of Particles: 219
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1697
# Number of Particles: 209
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1783
# Number of Particles: 188
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2102
# Number of Particles: 174
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1700
# Number of Particles: 211
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1908
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3091
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3079
# Number of Particles: 150
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 823
# Number of Particles: 185
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1494
# Number of Particles: 122
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1025
# Number of Particles: 178
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3246
# Number of Particles: 184
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3056
# Number of Particles: 157
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3114
# Number of Particles: 160
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3330
# Number of Particles: 179
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2939
# Number of Particles: 149
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3185
# Number of Particles: 166
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3003
# Number of Particles: 143
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3190
# Number of Particles: 157
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3321
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3039
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2749
# Number of Particles: 108
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2867
# Number of Particles: 140
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3138
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2979
# Number of Particles: 135
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3253
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3184
# Number of Particles: 172
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3170
# Number of Particles: 147
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2714
# Number of Particles: 128
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2783
# Number of Particles: 130
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3171
# Number of Particles: 159
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2872
# Number of Particles: 133
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3094
# Number of Particles: 143
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2664
# Number of Particles: 129
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3067
# Number of Particles: 137
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3211
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2967
# Number of Particles: 163
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3309
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2959
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3198
# Number of Particles: 152
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3064
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3046
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3399
# Number of Particles: 194
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3597
# Number of Particles: 212
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3221
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3341
# Number of Particles: 184
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2955
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3112
# Number of Particles: 156
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3038
# Number of Particles: 145
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3270
# Number of Particles: 174
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3492
# Number of Particles: 195
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3571
# Number of Particles: 219
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3439
# Number of Particles: 204
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3578
# Number of Particles: 214
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3531
# Number of Particles: 178
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3373
# Number of Particles: 197
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3490
# Number of Particles: 221
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3107
# Number of Particles: 172
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3556
# Number of Particles: 207
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3604
# Number of Particles: 243
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3606
# Number of Particles: 217
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3616
# Number of Particles: 212
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3584
# Number of Particles: 238
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3608
# Number of Particles: 215
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3537
# Number of Particles: 200
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3602
# Number of Particles: 207
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3512
# Number of Particles: 214
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3393
# Number of Particles: 196
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3365
# Number of Particles: 198
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3389
# Number of Particles: 185
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3534
# Number of Particles: 214
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2796
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3376
# Number of Particles: 172
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3030
# Number of Particles: 126
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3016
# Number of Particles: 151
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3053
# Number of Particles: 150
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3143
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3141
# Number of Particles: 154
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2967
# Number of Particles: 139
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3117
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3028
# Number of Particles: 141
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2863
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3168
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3230
# Number of Particles: 160
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3154
# Number of Particles: 149
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2937
# Number of Particles: 138
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3228
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3423
# Number of Particles: 190
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3243
# Number of Particles: 162
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3421
# Number of Particles: 193
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3388
# Number of Particles: 207
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3263
# Number of Particles: 170
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3173
# Number of Particles: 160
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3185
# Number of Particles: 177
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3447
# Number of Particles: 191
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2849
# Number of Particles: 130
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3217
# Number of Particles: 163
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3301
# Number of Particles: 179
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3301
# Number of Particles: 173
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3433
# Number of Particles: 191
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3166
# Number of Particles: 157
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3102
# Number of Particles: 156
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3320
# Number of Particles: 169
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3041
# Number of Particles: 149
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3303
# Number of Particles: 169
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3393
# Number of Particles: 179
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3164
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2958
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3235
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3302
# Number of Particles: 178
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2736
# Number of Particles: 123
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2527
# Number of Particles: 107
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2374
# Number of Particles: 97
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2661
# Number of Particles: 117
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2931
# Number of Particles: 129
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2315
# Number of Particles: 87
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2935
# Number of Particles: 141
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2853
# Number of Particles: 121
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2822
# Number of Particles: 136
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2767
# Number of Particles: 138
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2297
# Number of Particles: 80
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3032
# Number of Particles: 132
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2221
# Number of Particles: 83
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2554
# Number of Particles: 100
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2821
# Number of Particles: 132
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2850
# Number of Particles: 136
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2928
# Number of Particles: 136
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2960
# Number of Particles: 137
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2986
# Number of Particles: 136
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3389
# Number of Particles: 167
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3038
# Number of Particles: 130
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2965
# Number of Particles: 116
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3067
# Number of Particles: 155
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2711
# Number of Particles: 124
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2552
# Number of Particles: 107
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2551
# Number of Particles: 106
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2586
# Number of Particles: 125
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2969
# Number of Particles: 138
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3016
# Number of Particles: 140
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2757
# Number of Particles: 127
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2869
# Number of Particles: 126
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2864
# Number of Particles: 126
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3273
# Number of Particles: 185
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2943
# Number of Particles: 139
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2866
# Number of Particles: 128
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2845
# Number of Particles: 121
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3142
# Number of Particles: 144
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2675
# Number of Particles: 111
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2595
# Number of Particles: 116
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2635
# Number of Particles: 104
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3084
# Number of Particles: 135
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2819
# Number of Particles: 131
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2672
# Number of Particles: 115
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2825
# Number of Particles: 120
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2909
# Number of Particles: 135
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2924
# Number of Particles: 135
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2868
# Number of Particles: 133
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3523
# Number of Particles: 196
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3637
# Number of Particles: 227
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3562
# Number of Particles: 206
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3599
# Number of Particles: 229
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3375
# Number of Particles: 192
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3605
# Number of Particles: 216
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3392
# Number of Particles: 201
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2726
# Number of Particles: 106
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2176
# Number of Particles: 90
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 1641
# Number of Particles: 101
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2324
# Number of Particles: 99
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2134
# Number of Particles: 82
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2085
# Number of Particles: 95
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2017
# Number of Particles: 84
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2586
# Number of Particles: 109
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2554
# Number of Particles: 106
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2956
# Number of Particles: 137
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3015
# Number of Particles: 138
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2806
# Number of Particles: 114
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2930
# Number of Particles: 127
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3232
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3178
# Number of Particles: 141
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3316
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3180
# Number of Particles: 165
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3495
# Number of Particles: 196
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3537
# Number of Particles: 208
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3377
# Number of Particles: 170
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3211
# Number of Particles: 158
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3344
# Number of Particles: 163
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3305
# Number of Particles: 163
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3520
# Number of Particles: 198
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3414
# Number of Particles: 185
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3194
# Number of Particles: 155
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3140
# Number of Particles: 148
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2992
# Number of Particles: 142
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3124
# Number of Particles: 162
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2929
# Number of Particles: 139
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2820
# Number of Particles: 130
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2830
# Number of Particles: 132
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3223
# Number of Particles: 153
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2280
# Number of Particles: 93
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3422
# Number of Particles: 187
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3189
# Number of Particles: 157
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3223
# Number of Particles: 166
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3374
# Number of Particles: 169
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 2572
# Number of Particles: 115
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3096
# Number of Particles: 146
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3200
# Number of Particles: 163
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3348
# Number of Particles: 192
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3448
# Number of Particles: 181
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3489
# Number of Particles: 204
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3336
# Number of Particles: 181
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3341
# Number of Particles: 191
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3106
# Number of Particles: 156
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3105
# Number of Particles: 164
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3445
# Number of Particles: 195
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3664
# Number of Particles: 242
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3402
# Number of Particles: 184
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3480
# Number of Particles: 190
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3435
# Number of Particles: 202
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3681
# Number of Particles: 227
# get score gpu 16 16 240 240 61 154
# get Max3 16 16 4 4 100 other :  61 3838 3838 63 3969
# convert
# Number of Particles before: 3444
# Number of Particles: 204

# %%
import matplotlib
for idx, (test_image, _, grid, _) in enumerate(full_dataset):
    # if idx == 6:
    #     break
    if idx % 30 == 0:
    # else:
        label_image = label_images[idx]
        _, ax = plt.subplots(figsize=(12, 12))
        ax.imshow(processed_micrographs[idx], cmap='gray')
        ax.imshow(label_image, cmap='inferno', alpha=0.4)

        for indx in nms_list[idx]:
            x, y = indx
            c = matplotlib.patches.Circle((x, y), radius=RADIUS, fill=False, color='r')
            ax.add_patch(c)
        plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

for idx, fname in enumerate(fnames):
    # Create the adjusted list of tuples for current index
    adjusted_c_list = [(x + BORDER, y + BORDER) for x, y in nms_list[idx]]

    # Create a temporary DataFrame from the list of tuples
    temp_df = pd.DataFrame(adjusted_c_list, columns=['rlnCoordinateX', 'rlnCoordinateY'])
    temp_df['rlnImageName'] = [f"{i:05d}@{fname}.mrc" for i in range(len(temp_df))]
    temp_df['rlnMicrographName'] = fname + ".mrc"

    # If this is the first DataFrame, initialize df
    if idx == 0:
        df = temp_df
    else:
        # Append the temporary DataFrame to the existing df
        df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#        rlnCoordinateX  rlnCoordinateY                      rlnImageName  \
# 0              2831.8          2374.2  00000@HCN1apo_0030_2xaligned.mrc
# 1               413.0           622.0  00001@HCN1apo_0030_2xaligned.mrc
# 2              3044.4          1630.2  00002@HCN1apo_0030_2xaligned.mrc
# 3               349.0           285.0  00003@HCN1apo_0030_2xaligned.mrc
# 4              1700.0          2001.0  00004@HCN1apo_0030_2xaligned.mrc
# ...               ...             ...                               ...
# 45318          2351.0          3233.0  00199@HCN1apo_1060_2xaligned.mrc
# 45319           121.2          2048.0  00200@HCN1apo_1060_2xaligned.mrc
# 45320          3611.0          2712.0  00201@HCN1apo_1060_2xaligned.mrc
# 45321          3577.0          2576.0  00202@HCN1apo_1060_2xaligned.mrc
# 45322           453.0          3421.0  00203@HCN1apo_1060_2xaligned.mrc
#
#                 rlnMicrographName
# 0      HCN1apo_0030_2xaligned.mrc
# 1      HCN1apo_0030_2xaligned.mrc
# 2      HCN1apo_0030_2xaligned.mrc
# 3      HCN1apo_0030_2xaligned.mrc
# 4      HCN1apo_0030_2xaligned.mrc
# ...                           ...
# 45318  HCN1apo_1060_2xaligned.mrc
# 45319  HCN1apo_1060_2xaligned.mrc
# 45320  HCN1apo_1060_2xaligned.mrc
# 45321  HCN1apo_1060_2xaligned.mrc
# 45322  HCN1apo_1060_2xaligned.mrc
#
# [45323 rows x 4 columns]

# %%
starfile.write(df, f'{RESULT_DIR}/nms_particles.star')
